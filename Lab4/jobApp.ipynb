# %%
from tkinter import *
root = tk.Tk()
root.geometry("412x717")
# bg = tk.Label(root,bg = "brown",width = "412").grid(row = 0,column = 0)
label = Label(root, text='Job Application',font = "Bold").grid(row = 13,column = 10)
Type = Label(root,text = "Personal Information",fg = "brown").grid(row = 20,column = 0)
name = Label(root ,text = "Name ").grid(row = 23,column = 0)
Fbox = Entry(root).grid(row = "23",column = 1)
Fname = Label(root ,text = "First Name").grid(row = 24,column = 1)
Lbox = Entry(root).grid(row = 23,column = 4)
Lname = Label(root ,text = "Last  Name ").grid(row = 24,column = 4)
email = Label(root ,text = "Email").grid(row = 26,column = 0)
Ebox = Entry(root,text = "user@example.com").grid(row = 26,column = 1)
Eduacation = Label(root ,text = "Education").grid(row = 28,column = 0)
# education = StringVar()
# education = tk.OptionMenu(root,width=4,textvariable=education).place(row = 28,column = 1)
# education['values'] =('Primary','Secondary','Btech','Mtech','MBA') 










root.mainloop()

# %%
from tkinter import filedialog
from tkinter import ttk

root = Tk()
root.title("Registration Form")
root.geometry("412x717")
heading = Label(root,text = "JOB APPLICATION",fg="black", font=("Helvetica"))
heading1 = Label(root,text = "Personal Information\n",fg='red', font=("Helvetica", 15))
name = Label(root,text = "Name\n")
email = Label(root,text = "Email\n")
education = Label(root,text = "Education\n")
resume = Label(root,text = "Resume\n")
address = Label(root,text = "Address\n")
phonenumber = Label(root,text = "Phone Number\n")
hobbies = Label(root,text = "What are your hobbies?")
blank = Label(root,text="")
heading2 = Label(root,text = "Precious/Current Emplotment Details",fg='red', font=("Helvetica", 14))
companyname = Label(root,text = "Company Name\n")
jobtitle = Label(root,text = "Job Title\n")
experience = Label(root,text = "how long were you\nhere ?(in months)\n")

heading3 = Label(root,text = "Reference #1",fg='red', font=("Helvetica", 14))
name1 = Label(root,text = "Name\n")
Phone1 = Label(root,text = "Phone\n")

heading4 = Label(root,text = "Reference #2",fg='red', font=("Helvetica", 14))
name2 = Label(root,text = "Name\n")
Phone2 = Label(root,text = "Phone")


heading.grid(row=0,column=0,columnspan=25,sticky="n")
heading1.grid(row=1,column = 0,columnspan=3,sticky="w")
name.grid(row=2,column=0,sticky="w")
email.grid(row=3,column=0,sticky="w")
education.grid(row=4,column=0,sticky="w")
resume.grid(row=5,column=0,sticky="w")
address.grid(row=6,column=0,sticky="w")
phonenumber.grid(row=10,column=0,sticky="w")
hobbies.grid(row=11,column=0,sticky="w")



heading2.grid(row=14,column=0,columnspan=3,sticky="w")
companyname.grid(row=15,column=0,sticky="w") 
jobtitle.grid(row=16,column=0,sticky="w")
experience.grid(row=17,column=0,sticky="w")

heading3.grid(row=18,column=0,sticky="w")
name1.grid(row=19,column=0,sticky="w") 
Phone1.grid(row=20,column=0,sticky="w")

heading4.grid(row=21,column=0,sticky="w")
name2.grid(row=22,column=0,sticky="w") 
Phone2.grid(row=23,column=0,sticky="w")

box = ttk.Combobox(root,width = 20,values = ['Please choose','Btech'])
box.grid(row=4,column=1,sticky="w")

name_field1 = Entry(root,width = 10)
name_field2 = Entry(root,width = 10)
email_field = Entry(root) 
 
def UploadAction(event=None):
    filename = filedialog.askopenfilename()
    print('Selected:', filename)
    return filename


button = Button(root,width= 10,height = 1, text='Choose file', command=UploadAction)
button.grid(row=5,column=1)
address1_field = Entry(root)
address2_field = Entry(root)
box = ttk.Combobox(root,width = 20,values = ['INDIA','USA','CANADA'])
box.insert(0,"Select a Country")
box.grid(row=8,column=1,sticky="w",pady=10) 
address4_1field = Entry(root,width = 10)
address4_2field = Entry(root,width = 10)
address4_3field = Entry(root,width =6)
phone_field = Entry(root) 
hobbies_field = Entry(root,width=50) 


heading3_field = Entry(root)
companyname_field = Entry(root) 
jobtitle_field = Entry(root)
experience_field = Entry(root)

heading3 = Entry(root)
name1 = Entry(root)
Phone1 = Entry(root)

heading4 = Entry(root)
name2 = Entry(root)
Phone2 = Entry(root)



name_field1.grid(row=2,column=1,sticky="w")
name_field1.insert(0,"First Name")
name_field2.grid(row=2,column=1,columnspan=3)
name_field2.insert(0,"Last Name")
email_field.grid(row=3,column=1,sticky="w") 
email_field.insert(0,"user@example.com")


address1_field.grid(row=6,column=1,sticky="w")
address1_field.insert(0,"Address line 1")
address2_field.grid(row=7,column=1,sticky="w")
address2_field.insert(0,"Address line 2") 

address4_1field.grid(row=9,column=1,sticky="w")
address4_1field.insert(0,"City") 
address4_2field.grid(row=9,column=1,padx=100,pady=5,columnspan=3)
address4_2field.insert(0,"State")
address4_3field.grid(row=9,column=2,columnspan=3)
address4_3field.insert(0,"Zip") 
phone_field.grid(row=10,column=1,sticky="w") 
hobbies_field.grid(row=12,column = 0,columnspan=4) 

l0 = Label(root, text='     ')
l0.grid(row=13,column=0)

companyname_field.grid(row=15,column=1,sticky="w")
jobtitle_field.grid(row=16,column=1,sticky="w")
experience_field.grid(row=17,column=1,sticky="w")

name1.grid(row=19,column=1,sticky="w")
Phone1.grid(row=20,column=1,sticky="w")

name2.grid(row=22,column=1,sticky="w")
Phone2.grid(row=23,column=1,sticky="w")

l1 = Label(root, text='  \n   ')
l1.grid(row=24,column=0)

submit = Button(root, text="Apply")
submit.grid(row=25,column=0,columnspan=4)

root.mainloop()
