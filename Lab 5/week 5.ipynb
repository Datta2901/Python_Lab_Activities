# %%
from tkinter import *
from tkinter import filedialog
import sqlite3

my_conn = sqlite3.connect('my_db.db')

root = Tk()
root.title("Job Application")
root.geometry("700x800")


c1 = Canvas(root, bg="brown", height = 10,width=700)
c1.place(x=0,y=0)
r = c1.create_polygon(0,0,10,700, fill="brown")
job_app = Label(root, text = "Job Application",font="segoe 30",padx=200) 
job_app.place(x=10,y=20)

personal_info = Label(root, text = "Personal Information",font = "segoe 15",fg="brown")
personal_info.place(y=70)

name = Label(root, text = "Name:",font = "segoe 15")
name.place(y=100)
fname = Text(root,width = 22,height = 1,bg='white')
fname.place(x=300,y=107)
lname = Text(root,width = 22,height = 1,bg='white')
lname.place(x=500,y=107)

email = Label(root, text = "Email:", font = "segoe 15")
email.place(y=130)
mail = Text(root,width = 45,height = 1,bg='white')
mail.place(x=300,y=137)

edu = Label(root, text = "Education:", font = "segoe 15")
edu.place(y=160)

lst = []
lst += "Anna University",
lst += "SRM",
lst += "SSN",
lst += "VIT",

varList = StringVar(root)
varList.set("Please Choose                        ")
college = OptionMenu(root,varList,*lst)
college.place(x=296,y=160)


res = Label(root, text = "Resume:", font = "segoe 15")
res.place(y=190)
def UploadAction(event=None):
    filename = ""
    filename = filedialog.askopenfilename()
    print('Selected:', filename)

button = Button(root, text='Choose file', command=UploadAction)
button.place(x=297,y=195)

adr = Label(root, text = "Address:", font = "segoe 15")
adr.place(y=220)
adr1 = Text(root,width = 45,height = 1,bg='white')
adr1.place(x=300,y=227)
adr2 = Text(root,width = 45,height = 1,bg='white')
adr2.place(x=300,y=257)

cnt = []
cnt.append("India")
cnt.append("China")
cntList = StringVar(root)
cntList.set("Select a Country                        ")
country = OptionMenu(root,cntList,*cnt)
country.place(x=296,y=280)

adr3 = Text(root,width = 22,height = 1,bg='white')
adr3.place(x=300,y=317)
adr4 = Text(root,width = 8,height = 1,bg='white')
adr4.place(x=495,y=317)
adr5 = Text(root,width = 12,height = 1,bg='white')
adr5.place(x=570,y=317)

phno = Label(root, text = "Phone Number:", font = "segoe 10")
phno.place(y=340)
ph1 = Text(root,width = 3,height = 1,bg='white')
ph1.place(x=300,y=347)
ph2 = Text(root,width = 30,height = 1,bg='white')
ph2.place(x=330,y=347)

hob = Label(root, text = "What are your hobbies:", font = "segoe 10")
hob.place(y=360)
hobby = Text(root,width = 80,height = 1,bg='white')
hobby.place(x=10,y=377)

current_details = Label(root, text = "Precious/Current Employment details",font = "segoe 15",fg="brown")
current_details.place(y=400)

cname = Label(root, text = "Company Name:", font = "segoe 15")
cname.place(y=430)
cname1 = Text(root,width = 45,height = 1,bg='white')
cname1.place(x=300,y=437)

jtitle = Label(root, text = "Job Title:", font = "segoe 15")
jtitle.place(y=460)
job = Text(root,width = 45,height = 1,bg='white')
job.place(x=300,y=467)

howlong = Label(root, text = "How long were you here:", font = "segoe 15")
howlong.place(y=490)
timehere = Text(root,width = 45,height = 1,bg='white')
timehere.place(x=300,y=497)

ref1 = Label(root, text = "Reference 1",font = "segoe 15",fg="brown")
ref1.place(y=520)

ref1name = Label(root, text = "Name:", font = "segoe 15")
ref1name.place(y=550)
rn1 = Text(root,width = 45,height = 1,bg='white')
rn1.place(x=300,y=557)

ref1phone = Label(root, text = "Phone:", font = "segoe 15")
ref1phone.place(y=580)
rp1 = Text(root,width = 45,height = 1,bg='white')
rp1.place(x=300,y=587)

ref2 = Label(root, text = "Reference 2",font = "segoe 15",fg="brown")
ref2.place(y=610)

ref2name = Label(root, text = "Name:", font = "segoe 15")
ref2name.place(y=640)
rn2 = Text(root,width = 45,height = 1,bg='white')
rn2.place(x=300,y=647)

ref2phone = Label(root, text = "Phone:", font = "segoe 15")
ref2phone.place(y=670)
rp2 = Text(root,width = 45,height = 1,bg='white')
rp2.place(x=300,y=677)


button = Button(root, text='Apply',height = 3 ,width=25,bg = "brown",fg = "white", command=lambda: add_data())
button.place(x=270,y=710)

my_str = StringVar()
status = Label(root, textvariable = my_str, width = 10)
status.place(x=0,y=720)
my_str.set("Output")

def add_data():
    flag_validation=True
    my_fname = fname.get("1.0",END)
    my_lname = lname.get("1.0",END)
    my_email = mail.get("1.0",END)
    my_education = varList.get()
    my_resume = varList.get() #filename #check this
    my_add1 = adr1.get("1.0",END)
    my_add2 = adr2.get("1.0",END)
    my_country = cntList.get()
    my_city = adr3.get("1.0",END)
    my_state = adr4.get("1.0",END)
    my_pincode = adr5.get("1.0",END)
    my_phno1 = ph1.get("1.0",END)
    my_phno2 = ph2.get("1.0",END)
    my_hobby = hobby.get("1.0",END) # check this
    my_company = cname1.get("1.0",END)
    my_job = job.get("1.0",END)
    my_time = timehere.get("1.0",END)
    my_r1name = rn1.get("1.0",END)
    my_r1phno = rp1.get("1.0",END)
    my_r2name = rn2.get("1.0",END)
    my_r2phno = rp2.get("1.0",END)
    
    """
    #checking if the values entebrown are correct
    if(len(my_phno1) > 3 or len(my_pincode) != 6 or len(my_phno2) > 10):
        flag_validation = False
        
    try:
        val = int(my_phno1)
        val = int(my_phno2)
        val = int(my_pincode)
        val = int(my_r1phno)
        val = int(my_r2phno)
    except:
        flag_validation=False 
    """
    
    print(len(my_pincode))
        
    if(flag_validation):
        my_str.set("Adding data...")
        try:
            my_data = (my_fname,my_lname,my_email,my_education,my_resume,my_add1,my_add2,my_country,my_city,my_state,my_pincode,my_phno1,my_phno2,my_hobby,my_company,my_job,my_time,my_r1name,my_r1phno,my_r2name,my_r2phno)
            my_query = "INSERT INTO form values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)"
            my_conn.execute(my_query,my_data)
            my_conn.commit()
            x=my_conn.execute('''select last_insert_rowid()''')
            id=x.fetchone()
            my_str.set("ID:" + str(id[0]))
            
            fname.delete("1.0",END)
            lname.delete("1.0",END)
            mail.delete("1.0",END)
            adr1.delete("1.0",END)
            adr2.delete("1.0",END)
            adr4.delete("1.0",END)
            adr5.delete("1.0",END)
            adr3.delete("1.0",END)
            ph1.delete("1.0",END)
            ph2.delete("1.0",END)
            hobby.delete("1.0",END)
            cname1.delete("1.0",END)
            job.delete("1.0",END)
            timehere.delete("1.0",END)
            rn1.delete("1.0",END)
            rp1.delete("1.0",END)
            rn2.delete("1.0",END)
            rp2.delete("1.0",END)
            
            
        except sqlite3.Error as my_error:
            print(my_error)
            my_str.set(my_error)
    else:
        my_str.set("check inputs.")

root.mainloop()
my_conn.close()
# Out:
# 7

# %%
import sqlite3
my_conn = sqlite3.connect('my_db.db')
print("Connected to database successfully")

try:
    my_conn.execute('''
        CREATE TABLE IF NOT EXISTS form(fname text primary key, 
                      lname text, 
                      email text, 
                      education text,
                      resume text,
                      add1 text,
                      add2 text,
                      country text,
                      city text,
                      state text,
                      pincode integer,
                      phno1 integer,
                      phno2 integer,
                      hobby text,
                      company text,
                      job text,
                      time text,
                      r1name text,
                      r1phno text,
                      r2name text,
                      r2phno text
                      );''')
    my_conn.commit()
    print("Student Table created successfully")
except sqlite3.Error as my_error:
  print("error: ",my_error)
# Out:
# Connected to database successfully
# Student Table created successfully

# %%
import sqlite3
my_conn = sqlite3.connect('my_db.db')
print("Connected to database successfully")

my_conn.execute('''DROP TABLE form;''')
print("table deleted")
# Out:
# Connected to database successfully
# table deleted

# %%
import sqlite3
my_conn = sqlite3.connect('my_db.db')

import tkinter  as tk 
from tkinter import * 
my_w = tk.Tk()
my_w.geometry("1500x250") 
my_w.config(bg = 'red')
r_set=my_conn.execute('''SELECT * from form''');
i=0 # row value inside the loop 
for enter in r_set: 
    for j in range(len(enter)):
        e = Entry(my_w, width=10, fg='blue') 
        e.grid(row=i, column=j) 
        e.insert(END, enter[j])
    i=i+1
my_w.mainloop()
